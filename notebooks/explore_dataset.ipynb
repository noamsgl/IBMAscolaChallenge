# %% [markdown]
# ## Load

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

filepath = "../datasets/universal_error/V1/U3_6_6.csv"
df = pd.read_csv(filepath)
# reorder columns
df = df[['theta', 'phi', 'lam', 'E', 'depol_prob', 't1', 't2', 'p0_0', 'p0_1', 'p1_0', 'p1_1']]

# %% [markdown]
# ## Peek

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1679616 entries, 0 to 1679615
# Data columns (total 11 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   theta       1679616 non-null  float64
#  1   phi         1679616 non-null  float64
#  2   lam         1679616 non-null  float64
#  3   E           1679616 non-null  float64
#  4   depol_prob  1679616 non-null  float64
#  5   t1          1679616 non-null  float64
#  6   t2          1679616 non-null  float64
#  7   p0_0        1679616 non-null  float64
#  8   p0_1        1679616 non-null  float64
#  9   p1_0        1679616 non-null  float64
#  10  p1_1        1679616 non-null  float64
# dtypes: float64(11)
# memory usage: 141.0 MB

# %%
df.head()
# Out:
#    theta  phi  lam         E  depol_prob       t1        t2  p0_0  p0_1  p1_0  \
# 0    0.0  0.0  0.0  0.924805         0.0  64845.0  16211.25  0.94  0.06  0.06
# 1    0.0  0.0  0.0  0.951172         0.2  64845.0  16211.25  0.94  0.06  0.06
# 2    0.0  0.0  0.0  0.950195         0.4  64845.0  16211.25  0.94  0.06  0.06
# 3    0.0  0.0  0.0  0.936523         0.6  64845.0  16211.25  0.94  0.06  0.06
# 4    0.0  0.0  0.0  0.945312         0.8  64845.0  16211.25  0.94  0.06  0.06
#
#    p1_1
# 0  0.94
# 1  0.94
# 2  0.94
# 3  0.94
# 4  0.94

# %% [markdown]
# ## Visualize

# %% [markdown]
# ### Histograms

# %%
sns.set(style='whitegrid', palette='deep', font_scale=1.1, rc={'figure.figsize': [8, 5]})
sns.distplot(df['E'], norm_hist=False, kde=False, bins=20, hist_kws={'alpha': 1}).set(xlabel="'Expected Value", ylabel='Count')
# Out:
# [Text(0, 0.5, 'Count'), Text(0.5, 0, "'Expected Value")]

# %%
df.hist(bins=15, figsize=(20,15), layout=(3,4));

# %% [markdown]
# ### Scatter Plots

# %%
sns.scatterplot(x=df['theta'], y=df['E']);

# %%
sns.scatterplot(x=df['phi'], y=df['E']);

# %%
sns.scatterplot(x=df['lam'], y=df['E']);

# %%
sns.scatterplot(x=df['theta'], y=df['phi']);

# %% [markdown]
# ### Pair Plots

# %%
sns.pairplot(data=df.sample(1000));

# %%
sns.pairplot(data=df.sample(10000));
